# %%
from helper import get_recommendations, get_dataframe
import pandas as pd

# %%
df = get_dataframe()
df.head()
# Out:
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                    genre_names  \
# 0  Action, Adventure, Fantasy, Science Fiction
# 1                   Adventure, Fantasy, Action
# 2                     Action, Adventure, Crime
# 3               Action, Crime, Drama, Thriller
# 4           Action, Adventure, Science Fiction
#
#                                             overview release_date  runtime  \
# 0  In the 22nd century, a paraplegic Marine is di...   2009-12-10      162
# 1  Captain Barbossa, long believed to be dead, ha...   2007-05-19      169
# 2  A cryptic message from Bond’s past sends him o...   2015-10-26      148
# 3  Following the death of District Attorney Harve...   2012-07-16      165
# 4  John Carter is a war-weary, former military ca...   2012-03-07      132
#
#    vote_average  vote_count  popularity  \
# 0           7.2       11800  150.437577
# 1           6.9        4500  139.082615
# 2           6.3        4466  107.376788
# 3           7.6        9106  112.312950
# 4           6.1        2124   43.926995
#
#                                              summary
# 0  Title: Avatar\n\nOverview: In the 22nd century...
# 1  Title: Pirates of the Caribbean: At World's En...
# 2  Title: Spectre\n\nOverview: A cryptic message ...
# 3  Title: The Dark Knight Rises\n\nOverview: Foll...
# 4  Title: John Carter\n\nOverview: John Carter is...

# %%
import random 

# 10 random title and 10 recommendations (only title)
for i in range(10):
    random_title = random.choice(df["original_title"])
    print(f"Title: {random_title}\n\nRecommendations:\n")
    print(get_recommendations(title=random_title), "\n\n")
# Out:
# Title: All the Real Girls
#
# Recommendations:
#
# 3806                                  The Spectacular Now
# 318                                          The Campaign
# 1679                                           Safe Haven
# 4428                                          The Gallows
# 593                                          Rock of Ages
# 2819                              The Secret Life of Bees
# 1892                                      Say It Isn't So
# 4348    The Incredibly True Adventure of Two Girls In ...
# 4383                                             Swingers
# 3286                                               Grease
# Name: original_title, dtype: object
#
#
# Title: The Darkest Hour
#
# Recommendations:
#
# 3822                        U.F.O.
# 3952        Independence Daysaster
# 368                      The Saint
# 2854    E.T. the Extra-Terrestrial
# 577            Battle: Los Angeles
# 169        The World Is Not Enough
# 964                       The Host
# 534                     Titan A.E.
# 576        Star Trek: Insurrection
# 1255                      Impostor
# Name: original_title, dtype: object
#
#
# Title: Katy Perry: Part of Me
#
# Recommendations:
#
# 2498                          Flicka
# 713     Michael Jackson's This Is It
# 1652                    Serving Sara
# 3791                 A Haunted House
# 4226                       Woodstock
# 2686                        Infamous
# 777                        Mortdecai
# 2921       One Direction: This Is Us
# 1946               Final Destination
# 2652            The Butterfly Effect
# Name: original_title, dtype: object
#
#
# Title: 3:10 to Yuma
#
# Recommendations:
#
# 865                     Shaft
# 3550                   Maggie
# 2376           The Apparition
# 3499             Take Shelter
# 944     Beverly Hills Cop III
# 3362                The Sting
# 2787    Welcome to Collinwood
# 1416         American Outlaws
# 1144          The Conjuring 2
# 1362                 Old Dogs
# Name: original_title, dtype: object
#
#
# Title: Hostel
#
# Recommendations:
#
# 2646               St. Vincent
# 593               Rock of Ages
# 3802               Saving Face
# 3240     Chairman of the Board
# 4393                   Baghead
# 2168    Code Name: The Cleaner
# 4290            Mutual Friends
# 669                  Astro Boy
# 3366                   Don Jon
# 3099                Club Dread
# Name: original_title, dtype: object
#
#
# Title: U2 3D
#
# Recommendations:
#
# 588                 The Dilemma
# 1902        Me and Orson Welles
# 2178                Topsy-Turvy
# 1576            The Running Man
# 1667              The Big Short
# 3062    Glee: The Concert Movie
# 3739               Bachelorette
# 944       Beverly Hills Cop III
# 4375         Along the Roadside
# 1491           Cradle Will Rock
# Name: original_title, dtype: object
#
#
# Title: Waterworld
#
# Recommendations:
#
# 76                        G.I. Joe: The Rise of Cobra
# 2770                                         Fortress
# 2090                                       Ghost Ship
# 1452                                 The Darkest Hour
# 509                             Ice Age: The Meltdown
# 3623                                       The Pirate
# 17        Pirates of the Caribbean: On Stranger Tides
# 841     The Pirates! In an Adventure with Scientists!
# 4319                                     My Dog Tulip
# 432              Alvin and the Chipmunks: Chipwrecked
# Name: original_title, dtype: object
#
#
# Title: The Giver
#
# Recommendations:
#
# 1556             P.S. I Love You
# 3169             Hostel: Part II
# 3676                   Beginners
# 3473               Lovely, Still
# 1138        Fifty Shades of Grey
# 2624              The Lucky Ones
# 2914    Kung Pow: Enter the Fist
# 2975                 The Joneses
# 3017               Adventureland
# 2912             The Perfect Man
# Name: original_title, dtype: object
#
#
# Title: The Matrix Reloaded
#
# Recommendations:
#
# 122                       The Matrix Revolutions
# 2881                                    Commando
# 2905                                  Sugar Hill
# 629                                   The Matrix
# 1599                                    Mr. 3000
# 1601                                 Ultraviolet
# 3275    The Work and the Glory II: American Zion
# 277                   Terminator 2: Judgment Day
# 3982                                   Insidious
# 2946                          The Straight Story
# Name: original_title, dtype: object
#
#
# Title: The Vatican Tapes
#
# Recommendations:
#
# 4090            The Devil Inside
# 4227    The Kentucky Fried Movie
# 3791             A Haunted House
# 4073       The Vatican Exorcisms
# 2070                   Spotlight
# 2156              Be Kind Rewind
# 3937           The Last Exorcism
# 2830                     Frailty
# 4147              Jimmy and Judy
# 3610                    The Veil
# Name: original_title, dtype: object

# %%
# 10 random title and 5 recommendations (only title)
for i in range(10):
    random_title = random.choice(df["original_title"])
    print(f"Title: {random_title}\n\nRecommendations:\n")
    print(get_recommendations(title=random_title, n_recomm=5), "\n\n")
# Out:
# Title: The Waterboy
#
# Recommendations:
#
# 658        We Are Marshall
# 4264    The Slaughter Rule
# 4427     Facing the Giants
# 3336       The 5th Quarter
# 2481    The Great Debaters
# Name: original_title, dtype: object
#
#
# Title: 11:14
#
# Recommendations:
#
# 3199                                    Jumping the Broom
# 3877                                             Shortbus
# 4348    The Incredibly True Adventure of Two Girls In ...
# 3307                                        Sliding Doors
# 557                                           The Village
# Name: original_title, dtype: object
#
#
# Title: The Perfect Match
#
# Recommendations:
#
# 4193      The Young Unknowns
# 1826         Good Luck Chuck
# 1772                Rain Man
# 2003               Hit & Run
# 885     From Paris with Love
# Name: original_title, dtype: object
#
#
# Title: Blue Ruin
#
# Recommendations:
#
# 499     The Secret Life of Pets
# 4499                  Newlyweds
# 3029      Into the Grizzly Maze
# 2051              The Last Song
# 175                The Revenant
# Name: original_title, dtype: object
#
#
# Title: Country Strong
#
# Recommendations:
#
# 3905                    Plush
# 1917     Think Like a Man Too
# 1251                 Soul Men
# 2448    Coal Miner's Daughter
# 2608       New York, New York
# Name: original_title, dtype: object
#
#
# Title: Pearl Harbor
#
# Recommendations:
#
# 2534        A Mighty Heart
# 1836     Tora! Tora! Tora!
# 2440               Top Gun
# 2149    The Quiet American
# 3300       Duel in the Sun
# Name: original_title, dtype: object
#
#
# Title: Babylon A.D.
#
# Recommendations:
#
# 3889                 Six-String Samurai
# 3705                       Next Day Air
# 446                     The Book of Eli
# 1855                           EuroTrip
# 2091    A Very Harold & Kumar Christmas
# Name: original_title, dtype: object
#
#
# Title: Finding Forrester
#
# Recommendations:
#
# 2738                 How High
# 2113               To Die For
# 2581      Slumdog Millionaire
# 1375             Black Knight
# 1721    The Neverending Story
# Name: original_title, dtype: object
#
#
# Title: Timber Falls
#
# Recommendations:
#
# 4326                   Old Joy
# 1098       Victor Frankenstein
# 3904                 Eden Lake
# 2761    Rachel Getting Married
# 4157                Black Rock
# Name: original_title, dtype: object
#
#
# Title: Transformers: Dark of the Moon
#
# Recommendations:
#
# 35      Transformers: Revenge of the Fallen
# 1756                               Brothers
# 110                            Transformers
# 217                            Jason Bourne
# 458                           Lost in Space
# Name: original_title, dtype: object

# %%
# 10 random title and 3 recommendations (with summary!)

for i in range(10):
    random_title = random.choice(df["original_title"])
    print(f"Random Title: {random_title}\n\n\nRecommendations:\n")
    recommendations = get_recommendations(title=random_title, n_recomm=3, only_title=False)
    for recommendation in recommendations:
        print(recommendation, "\n\n\n")
# Out:
# Random Title: Bandslam
#
#
# Recommendations:
#
# Title: 21 Jump Street
#
# Overview: In high school, Schmidt was a dork and Jenko was the popular jock. After graduation, both of them joined the police force and ended up as partners riding bicycles in the city park. Since they are young and look like high school students, they are assigned to an undercover unit to infiltrate a drug ring that is supplying high school students synthetic drugs.
#
# Genres: Action, Comedy, Crime
#
# Release: 2012-03-12 00:00:00
#
# Runtime: 109 min
#
# Voting Average: 6.7
#
#
#
# Title: Here Comes the Boom
#
# Overview: A high school biology teacher moonlights as a mixed-martial arts fighter in an effort to raise money to save the school's music program.
#
# Genres: Comedy
#
# Release: 2012-10-11 00:00:00
#
# Runtime: 105 min
#
# Voting Average: 6.0
#
#
#
# Title: Easy A
#
# Overview: After a little white lie about losing her virginity gets out, a clean cut high school girl sees her life paralleling Hester Prynne's in "The Scarlet Letter," which she is currently studying in school - until she decides to use the rumor mill to advance her social and financial standing.
#
# Genres: Comedy
#
# Release: 2010-09-10 00:00:00
#
# Runtime: 92 min
#
# Voting Average: 6.7
#
#
#
# Random Title: Traffic
#
#
# Recommendations:
#
# Title: Clear and Present Danger
#
# Overview: CIA Analyst Jack Ryan is drawn into an illegal war fought by the US government against a Colombian drug cartel.
#
# Genres: Action, Drama, Thriller
#
# Release: 1994-08-03 00:00:00
#
# Runtime: 141 min
#
# Voting Average: 6.4
#
#
#
# Title: Casa De Mi Padre
#
# Overview: Scheming of a way to save their father's ranch, the Alvarez brothers find themselves in a war with Mexico's most feared drug lord.
#
# Genres: Comedy, Western
#
# Release: 2012-03-15 00:00:00
#
# Runtime: 84 min
#
# Voting Average: 5.5
#
#
#
# Title: A Walk Among the Tombstones
#
# Overview: Private investigator Matthew Scudder is hired by a drug kingpin to find out who kidnapped and murdered his wife.
#
# Genres: Crime, Drama, Mystery, Thriller
#
# Release: 2014-09-18 00:00:00
#
# Runtime: 113 min
#
# Voting Average: 6.2
#
#
#
# Random Title: Boys and Girls
#
#
# Recommendations:
#
# Title: Kiss the Bride
#
# Overview: In high school, Matt and Ryan were best friends. More than friends, actually. But in the ensuing ten years, they've lost contact. So when Matt receives an invitation to Ryan's wedding he's surprised - especially that Ryan is marrying a woman!
#
# Genres: Drama, Comedy, Romance
#
# Release: 2007-01-01 00:00:00
#
# Runtime: 100 min
#
# Voting Average: 4.2
#
#
#
# Title: Up in the Air
#
# Overview: George Clooney plays the dry cynical character of Ryan Bingham, an executive who specializes in "downsizing". Ryan lives out of his suitcase, traveling the country for the sole purpose terminating unwanted employees day after day. Just as Ryan is about to reach his life-long goal of the ten million mile frequent flyer mark some major changes come his way. Changes that threaten to crack the cold heartless exterior that is Ryan Bingham.
#
# Genres: Drama, Romance
#
# Release: 2009-09-05 00:00:00
#
# Runtime: 109 min
#
# Voting Average: 6.7
#
#
#
# Title: Meet the Fockers
#
# Overview: Hard-to-crack ex-CIA man, Jack Byrnes and his wife, Dina head for the warmer climes of Florida to meet son-in-law-to-be, Greg Focker's parents. Unlike their happily matched offspring, the future in-laws find themselves in a situation of opposites that definitely do not attract.
#
# Genres: Comedy, Romance
#
# Release: 2004-12-22 00:00:00
#
# Runtime: 115 min
#
# Voting Average: 6.1
#
#
#
# Random Title: Bowfinger
#
#
# Recommendations:
#
# Title: An American in Hollywood
#
# Overview: A talented young filmmaker from New York sets off to Los Angeles in pursuit of the Hollywood dream, only to discover through his relationship with a beautiful feisty young actress, that Hollywood is not all that it seems.
#
# Genres:
#
# Release: 2014-07-18 00:00:00
#
# Runtime: 89 min
#
# Voting Average: 0.0
#
#
#
# Title: Kit Kittredge: An American Girl
#
# Overview: The Great Depression hits home for nine year old Kit Kittredge when her dad loses his business and leaves to find work. Oscar nominee Abigail Breslin stars as Kit, leading a splendid cast in the first ever "American Girl" theatrical movie. In order to keep their home, Kit and her mother must take in boarders - paying house - guests who turn out to be full of fascinating stories. When mother's lockbox containing all their money is stolen, Kit's new hobo friend Will is the prime suspect. Kit refuses to believe that Will would steal, and her efforts to sniff out the real story get her and friends into big trouble. The police say the robbery was an inside job, committed by someone they know. So if it wasn't Will, then who did it.
#
# Genres: Comedy, Drama, Family
#
# Release: 2008-07-02 00:00:00
#
# Runtime: 101 min
#
# Voting Average: 6.4
#
#
#
# Title: Silent Movie
#
# Overview: Aspiring filmmakers Mel Funn, Marty Eggs and Dom Bell go to a financially troubled studio with an idea for a silent movie. In an effort to make the movie more marketable, they attempt to recruit a number of big name stars to appear, while the studio's creditors attempt to thwart them. The film contains only one word of dialogue, spoken by an unlikely source.
#
# Genres: Comedy
#
# Release: 1976-06-17 00:00:00
#
# Runtime: 86 min
#
# Voting Average: 6.7
#
#
#
# Random Title: City Island
#
#
# Recommendations:
#
# Title: Eulogy
#
# Overview: A black comedy that follows three generations of a family, who come together for the funeral of the patriarch - unveiling a litany of family secrets and covert relationships.
#
# Genres: Comedy, Drama
#
# Release: 2004-10-15 00:00:00
#
# Runtime: 91 min
#
# Voting Average: 6.4
#
#
#
# Title: Opposite Sex
#
# Overview: A Bet's A Bet tells the story of Vince, New England's most successful divorce attorney. To Vince, life is one big competition, and losing is unacceptable. This also applies in his dating life with his love 'em and leave 'em approach. Then Vince meets Jane, who is beautiful, successful and also extremely driven. Together they enter into a series of entertaining wagers with each other where the winner gets to decide the fate of the loser. After all, "A Bet's a Bet!"
#
# Genres: Comedy
#
# Release: 2014-11-08 00:00:00
#
# Runtime: 96 min
#
# Voting Average: 4.1
#
#
#
# Title: White Noise 2: The Light
#
# Overview: A man's family brought back from the verge of death, he then discovers he can identify people who are about to die.
#
# Genres: Thriller, Drama, Horror, Fantasy
#
# Release: 2007-01-05 00:00:00
#
# Runtime: 99 min
#
# Voting Average: 5.6
#
#
#
# Random Title: N-Secure
#
#
# Recommendations:
#
# Title: Snow White: A Deadly Summer
#
# Overview: A troubled teenage girl finds herself in a web of lies and deceit when her stepmother attempts to murder her by sending her to a discipline camp.
#
# Genres: Horror, Thriller
#
# Release: 2012-03-16 00:00:00
#
# Runtime: 85 min
#
# Voting Average: 4.8
#
#
#
# Title: Crazy/Beautiful
#
# Overview: At Pacific Palisades High, a poor Latino falls hard for a troubled girl from the affluent neighborhood.
#
# Genres: Drama, Romance
#
# Release: 2001-06-29 00:00:00
#
# Runtime: 99 min
#
# Voting Average: 6.6
#
#
#
# Title: Transsiberian
#
# Overview: A Trans-Siberian train journey from China to Moscow becomes a thrilling chase of deception and murder when an American couple encounters a mysterious pair of fellow travelers.
#
# Genres: Thriller, Crime, Mystery
#
# Release: 2008-01-18 00:00:00
#
# Runtime: 111 min
#
# Voting Average: 6.5
#
#
#
# Random Title: Volcano
#
#
# Recommendations:
#
# Title: Undiscovered
#
# Overview: A group of aspiring entertainers try to establish careers for themselves in the city of Los Angeles.
#
# Genres: Comedy, Romance
#
# Release: 2005-08-26 00:00:00
#
# Runtime: 97 min
#
# Voting Average: 4.5
#
#
#
# Title: Water & Power
#
# Overview: Twin brothers nicknamed "Water" and "Power" from the hard scrabble Eastside streets of Los Angeles rise like prince's through the city's political and police ranks to become players in a complex and dangerous web of the powerful and corrupt of Los Angeles.
#
# Genres: Crime, Drama
#
# Release: 2014-05-02 00:00:00
#
# Runtime: 0 min
#
# Voting Average: 3.0
#
#
#
# Title: Redbelt
#
# Overview: Is there room for principle in Los Angeles? Mike Terry teaches jujitsu and barely makes ends meet. His Brazilian wife, whose family promotes fights, wants to see Mike in the ring making money, but to him competition is degrading. A woman sideswipes Mike's car and then, after an odd sequence of events, shoots out the studio's window. Later that evening, Mike rescues an action movie star in a fistfight at a bar. In return, the actor befriends Mike, gives him a gift, offers him work on his newest film, and introduces Mike's wife to his own - the women initiate business dealings. Then, things go sour all at once, Mike's debts mount, and going into the ring may be his only option.
#
# Genres: Drama
#
# Release: 2008-04-07 00:00:00
#
# Runtime: 99 min
#
# Voting Average: 6.4
#
#
#
# Random Title: The Pelican Brief
#
#
# Recommendations:
#
# Title: The Front Page
#
# Overview: A journalist suffering from burn-out wants to finally say goodbye to his office – but his boss doesn’t like the idea one bit.
#
# Genres: Romance, Drama, Comedy
#
# Release: 1974-12-01 00:00:00
#
# Runtime: 105 min
#
# Voting Average: 6.9
#
#
#
# Title: Yes Man
#
# Overview: Carl Allen has stumbled across a way to shake free of post-divorce blues and a dead-end job: embrace life and say yes to everything.
#
# Genres: Comedy
#
# Release: 2008-12-09 00:00:00
#
# Runtime: 104 min
#
# Voting Average: 6.4
#
#
#
# Title: The Devil Wears Prada
#
# Overview: The Devil Wears Prada is about a young journalist who moves to New York to work in the fashion industry. Her boss however is extremely demanding and cruel and won’t let her succeed if she doesn’t fit into the high class elegant look of their magazine when all she really wants to be a good journalist.
#
# Genres: Comedy, Drama, Romance
#
# Release: 2006-06-30 00:00:00
#
# Runtime: 109 min
#
# Voting Average: 7.0
#
#
#
# Random Title: Lottery Ticket
#
#
# Recommendations:
#
# Title: Me Before You
#
# Overview: A small town girl is caught between dead-end jobs. A high-profile, successful man becomes wheelchair bound following an accident. The man decides his life is not worth living until the girl is hired for six months to be his new caretaker. Worlds apart and trapped together by circumstance, the two get off to a rocky start. But the girl becomes determined to prove to the man that life is worth living and as they embark on a series of adventures together, each finds their world changing in ways neither of them could begin to imagine.
#
# Genres: Drama, Romance
#
# Release: 2016-06-02 00:00:00
#
# Runtime: 110 min
#
# Voting Average: 7.6
#
#
#
# Title: All About the Benjamins
#
# Overview: Bucum Jackson (Cube) is a bounty hunter with a lot of attitude and no interest in taking on a partner. Working at Martinez Bail Bonds, Jackson has unorthodox methods of tracking down low-life criminals, but they work, and one day he hopes to become his own boss and open up his own private investigation firm. Reggie Wright (Epps) is a slippery con artist who is avoiding the law, and Jackson. During a cat and mouse chase, the two stumble on a multi-million dollar diamond heist. Hiding from Jackson, Wright finds himself in the thieves' getaway van and ends up having to escape from them after they discover their booty is fake, much to the displeasure of their ruthless boss (Flanagan). When Wright meets up with his girlfriend (Mendes), he discovers that his recently purchased lottery ticket is the sole winner of $60 million. Unfortunately, his wallet, which held the ticket, was left in the thieves' van, so he persuades Jackson to help him get it back.
#
# Genres: Action, Adventure, Comedy
#
# Release: 2002-03-08 00:00:00
#
# Runtime: 95 min
#
# Voting Average: 5.8
#
#
#
# Title: The Joneses
#
# Overview: A seemingly perfect family moves into a suburban neighborhood, but when it comes to the truth as to why they're living there, they don't exactly come clean with their neighbors.
#
# Genres: Comedy, Drama
#
# Release: 2009-09-13 00:00:00
#
# Runtime: 96 min
#
# Voting Average: 6.1
#
#
#
# Random Title: The Wizard of Oz
#
#
# Recommendations:
#
# Title: Legends of Oz: Dorothy's Return
#
# Overview: Dorothy wakes up in post-tornado Kansas, only to be whisked back to Oz to try to save her old friends the Scarecrow, the Lion, the Tin Man and Glinda from a devious new villain, the Jester. Wiser the owl, Marshal Mallow, China Princess and Tugg the tugboat join Dorothy on her latest magical journey through the colorful landscape of Oz to restore order and happiness to Emerald City.
#
# Genres: Animation, Music, Family
#
# Release: 2013-06-13 00:00:00
#
# Runtime: 88 min
#
# Voting Average: 5.9
#
#
#
# Title: Just Visiting
#
# Overview: A knight and his valet are plagued by a witch, and to repair the damage they make use of the services of a wizard. However, something goes wrong and they are transported from the 12th century to the year 2000. There the knight meets some of his family and slowly learns what this new century is like. However, he still needs to get back to the 12th century to deal with the witch, so he starts looking for a wizard.
#
# Genres: Comedy, Fantasy, Science Fiction
#
# Release: 2001-04-06 00:00:00
#
# Runtime: 88 min
#
# Voting Average: 4.8
#
#
#
# Title: Return to Oz
#
# Overview: Dorothy, saved from a psychiatric experiment by a mysterious girl, finds herself back in the land of her dreams, and makes delightful new friends, and dangerous new enemies.
#
# Genres: Adventure, Family, Fantasy
#
# Release: 1985-06-21 00:00:00
#
# Runtime: 109 min
#
# Voting Average: 6.7
